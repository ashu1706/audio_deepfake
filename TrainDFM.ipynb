# %%
from tensorflow.keras.models import load_model

# Load the previously trained model
model = load_model('audio_deepfake_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import librosa
import numpy as np
import torch
from transformers import Wav2Vec2Processor, Wav2Vec2Model

def load_and_preprocess_audio(file_path, target_sr=16000):
    # Load audio with Librosa, resampling to target_sr
    audio, sr = librosa.load(file_path, sr=target_sr)
    
    # Trim leading and trailing silence
    audio, _ = librosa.effects.trim(audio)
    
    # Perform noise reduction (simple method by subtracting mean)
    audio = audio - np.mean(audio)
    
    return audio, sr

# Initialize Wav2Vec processor and model for embeddings
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h")
model_wav2vec = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h")
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def extract_wav2vec_large_features(file_path):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=16000)  # Ensure the sampling rate is 16kHz
    
    # Prepare input
    input_values = processor(y, return_tensors="pt", sampling_rate=16000)

    # Check the structure of input_values
    print("Input values keys:", input_values.keys())  # Debugging line to see what keys are returned

    # Get features
    with torch.no_grad():
        outputs = model(**input_values)  # Use double asterisks to unpack the dictionary
        features = outputs.last_hidden_state.mean(dim=1)  # Average pooling over the sequence length

    return features.squeeze().numpy()  # Return as a numpy array

# %%
import librosa

def extract_mfcc(file_path, sr=16000, n_mfcc=13):
    audio, _ = librosa.load(file_path, sr=sr)
    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc)
    return mfccs.mean(axis=1)  # Averaging MFCCs over time

# %%
def extract_mel_spectrogram(file_path, sr=16000):
    audio, _ = librosa.load(file_path, sr=sr)
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)  # Convert to dB
    return mel_spectrogram_db

# %%
'''
def augment_audio(audio, sr, pitch_shift_steps=2, time_stretch_rate=1.2):
    # Pitch shifting
    augmented_audio = librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=pitch_shift_steps)
    
    # Time stretching
    augmented_audio = librosa.effects.time_stretch(augmented_audio, rate=time_stretch_rate)
    
    return augmented_audio
'''
# Out:
# '\ndef augment_audio(audio, sr, pitch_shift_steps=2, time_stretch_rate=1.2):\n    # Pitch shifting\n    augmented_audio = librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=pitch_shift_steps)\n    \n    # Time stretching\n    augmented_audio = librosa.effects.time_stretch(augmented_audio, rate=time_stretch_rate)\n    \n    return augmented_audio\n'

# %%
def preprocess_and_extract_features(file_path, augment=False):
    mfcc_features = extract_mfcc(file_path)
    mel_spectrogram_features = extract_mel_spectrogram(file_path)
    wav2vec_features = extract_wav2vec_large_features(file_path)  # Pass file_path directly

    return mfcc_features, mel_spectrogram_features, wav2vec_features

# %%
import os
import numpy as np
'''
def preprocess_and_extract_features(file_path, augment=False):
    # Load audio
    audio, sr = librosa.load(file_path, sr=16000)
    
    # Optionally augment audio
    if augment:
        audio = augment_audio(audio, sr)  # Ensure this function is defined

    # Extract features
    mfcc_features = extract_mfcc(file_path)
    mel_spectrogram_features = extract_mel_spectrogram(file_path)
    wav2vec_features = extract_wav2vec_large_features(audio)  # Updated to include padding

    return mfcc_features, mel_spectrogram_features, wav2vec_features
'''
    
def extract_features_from_dataset(dataset_path, augment=False):
    mfcc_features_list = []
    mel_spectrogram_features_list = []
    wav2vec_features_list = []
    labels = []

    for folder_name in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder_name)
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.wav'):  # Ensure you only process .wav files
                file_path = os.path.join(folder_path, file_name)
                mfcc, mel_spectrogram, wav2vec = preprocess_and_extract_features(file_path, augment=augment)
                
                mfcc_features_list.append(mfcc)
                mel_spectrogram_features_list.append(mel_spectrogram)
                wav2vec_features_list.append(wav2vec)
                
                # Append labels based on folder name
                if folder_name.lower() == 'real':
                    labels.append(1)  # Real
                else:
                    labels.append(0)  # Fake

    return np.array(mfcc_features_list), np.array(mel_spectrogram_features_list), np.array(wav2vec_features_list), np.array(labels)

# Usage
dataset_path = r'C:\Users\ACER\Desktop\ASV 2015\Train'  # Adjust path accordingly
mfcc_features, mel_spectrogram_features, wav2vec_features, labels = extract_features_from_dataset(dataset_path, augment=True)
print("MFCC Features shape:", mfcc_features.shape)
print("Mel Spectrogram Features shape:", mel_spectrogram_features.shape)
print("Wav2Vec Features shape:", wav2vec_features.shape)
print("Labels shape:", labels.shape)
# Out:
# Input values keys: dict_keys(['input_values'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 47
#      45 # Usage
#      46 dataset_path = r'C:\Users\ACER\Desktop\ASV 2015\Train'  # Adjust path accordingly
# ---> 47 mfcc_features, mel_spectrogram_features, wav2vec_features, labels = extract_features_from_dataset(dataset_path, augment=True)
#      48 print("MFCC Features shape:", mfcc_features.shape)
#      49 print("Mel Spectrogram Features shape:", mel_spectrogram_features.shape)
#
# Cell In[96], line 31, in extract_features_from_dataset(dataset_path, augment)
#      29 if file_name.endswith('.wav'):  # Ensure you only process .wav files
#      30     file_path = os.path.join(folder_path, file_name)
# ---> 31     mfcc, mel_spectrogram, wav2vec = preprocess_and_extract_features(file_path, augment=augment)
#      33     mfcc_features_list.append(mfcc)
#      34     mel_spectrogram_features_list.append(mel_spectrogram)
#
# Cell In[94], line 4, in preprocess_and_extract_features(file_path, augment)
#       2 mfcc_features = extract_mfcc(file_path)
#       3 mel_spectrogram_features = extract_mel_spectrogram(file_path)
# ----> 4 wav2vec_features = extract_wav2vec_large_features(file_path)  # Pass file_path directly
#       6 return mfcc_features, mel_spectrogram_features, wav2vec_features
#
# Cell In[86], line 13, in extract_wav2vec_large_features(file_path)
#      11 # Get features
#      12 with torch.no_grad():
# ---> 13     outputs = model(**input_values)  # Use double asterisks to unpack the dictionary
#      14     features = outputs.last_hidden_state.mean(dim=1)  # Average pooling over the sequence length
#      16 return features.squeeze().numpy()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anacond3\Lib\inspect.py:3267, in Signature.bind(self, *args, **kwargs)
#    3262 def bind(self, /, *args, **kwargs):
#    3263     """Get a BoundArguments object, that maps the passed `args`
#    3264     and `kwargs` to the function's signature.  Raises `TypeError`
#    3265     if the passed arguments can not be bound.
#    3266     """
# -> 3267     return self._bind(args, kwargs)
#
# File ~\anacond3\Lib\inspect.py:3180, in Signature._bind(self, args, kwargs, partial)
#    3178                 msg = 'missing a required{argtype} argument: {arg!r}'
#    3179                 msg = msg.format(arg=param.name, argtype=argtype)
# -> 3180                 raise TypeError(msg) from None
#    3181 else:
#    3182     # We have a positional argument to process
#    3183     try:
#
# TypeError: missing a required argument: 'inputs'

# %%
import numpy as np
import os

def pad_or_truncate_spectrogram(mel_spec, target_width=44):
    """Pad or truncate the Mel spectrogram to the target width."""
    current_width = mel_spec.shape[1]
    
    if current_width < target_width:
        # Pad with zeros on the right
        padding = target_width - current_width
        mel_spec = np.pad(mel_spec, ((0, 0), (0, padding)), mode='constant', constant_values=0)
    elif current_width > target_width:
        # Truncate the spectrogram
        mel_spec = mel_spec[:, :target_width]
    
    return mel_spec

def extract_features_from_new_dataset(dataset_path):
    mfcc_features, mel_spectrogram_features, wav2vec_features, labels = [], [], [], []

    for label in ['real', 'fake']:
        folder_path = os.path.join(dataset_path, label)
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            mfcc = extract_mfcc(file_path)
            mel_spec = extract_mel_spectrogram(file_path)  # Get the raw Mel spectrogram
            print(f"Raw Mel spectrogram shape for {file_name}: {mel_spec.shape}")  # Print the shape
            
            # Pad or truncate the Mel spectrogram
            mel_spec = pad_or_truncate_spectrogram(mel_spec, target_width=44)
            mel_spec = np.expand_dims(mel_spec, axis=-1)  # Add channel dimension

            wav2vec = extract_wav2vec_large_features(file_path)

            mfcc_features.append(mfcc)
            mel_spectrogram_features.append(mel_spec)
            wav2vec_features.append(wav2vec)
            labels.append(0 if label == 'real' else 1)

    return np.array(mfcc_features), np.array(mel_spectrogram_features), np.array(wav2vec_features), np.array(labels)

# Use the function to extract features from the new dataset
new_dataset_path = r'C:\Users\ACER\Desktop\ASV 2015\Train'
X_mfcc_new, X_mel_new, X_wav2vec_new, y_new = extract_features_from_new_dataset(new_dataset_path)

# Now X_mel_new should be shaped (num_samples, 128, 44, 1)
print("New MFCC shape:", X_mfcc_new.shape)
print("New Mel spectrogram shape:", X_mel_new.shape)
print("New Wav2Vec shape:", X_wav2vec_new.shape)
print("New Labels shape:", y_new.shape)
# Out:
# Keyword argument `sampling_rate` is not a valid argument for this processor and will be ignored.
# Raw Mel spectrogram shape for T13_1002558.wav: (128, 98)
# Raw Mel spectrogram shape for T13_1002560.wav: (128, 77)
# Raw Mel spectrogram shape for T13_1002562.wav: (128, 201)
# Raw Mel spectrogram shape for T13_1002564.wav: (128, 97)
# Raw Mel spectrogram shape for T13_1002567.wav: (128, 89)
# Raw Mel spectrogram shape for T13_1002573.wav: (128, 87)
# Raw Mel spectrogram shape for T13_1002584.wav: (128, 122)
# Raw Mel spectrogram shape for T13_1002587.wav: (128, 61)
# Raw Mel spectrogram shape for T13_1002589.wav: (128, 67)
# Raw Mel spectrogram shape for T13_1002599.wav: (128, 75)
# Raw Mel spectrogram shape for T13_1002603.wav: (128, 127)
# Raw Mel spectrogram shape for T13_1002654.wav: (128, 66)
# Raw Mel spectrogram shape for T13_1002688.wav: (128, 107)
# Raw Mel spectrogram shape for T16_1002857.wav: (128, 99)
# Raw Mel spectrogram shape for T16_1002861.wav: (128, 127)
# Raw Mel spectrogram shape for T16_1002863.wav: (128, 129)
# Raw Mel spectrogram shape for T16_1002864.wav: (128, 151)
# Raw Mel spectrogram shape for T16_1002869.wav: (128, 250)
# Raw Mel spectrogram shape for T16_1002873.wav: (128, 97)
# Raw Mel spectrogram shape for T16_1002883.wav: (128, 89)
# Raw Mel spectrogram shape for T16_1002892.wav: (128, 161)
# Raw Mel spectrogram shape for T16_1002904.wav: (128, 162)
# Raw Mel spectrogram shape for T16_1002912.wav: (128, 145)
# Raw Mel spectrogram shape for T16_1002920.wav: (128, 86)
# Raw Mel spectrogram shape for T16_1002928.wav: (128, 134)
# Raw Mel spectrogram shape for T16_1002935.wav: (128, 123)
# Raw Mel spectrogram shape for T16_1002946.wav: (128, 117)
# Raw Mel spectrogram shape for T16_1002948.wav: (128, 149)
# Raw Mel spectrogram shape for T16_1002950.wav: (128, 94)
# Raw Mel spectrogram shape for T16_1002963.wav: (128, 99)
# Raw Mel spectrogram shape for T16_1002980.wav: (128, 110)
# Raw Mel spectrogram shape for T16_1002983.wav: (128, 84)
# Raw Mel spectrogram shape for T17_1003151.wav: (128, 77)
# Raw Mel spectrogram shape for T17_1003171.wav: (128, 142)
# Raw Mel spectrogram shape for T17_1003173.wav: (128, 101)
# Raw Mel spectrogram shape for T17_1003174.wav: (128, 91)
# Raw Mel spectrogram shape for T17_1003202.wav: (128, 77)
# Raw Mel spectrogram shape for T17_1003212.wav: (128, 94)
# Raw Mel spectrogram shape for T17_1003217.wav: (128, 70)
# Raw Mel spectrogram shape for T17_1003219.wav: (128, 115)
# Raw Mel spectrogram shape for T17_1003221.wav: (128, 85)
# Raw Mel spectrogram shape for T17_1003236.wav: (128, 109)
# Raw Mel spectrogram shape for T17_1003246.wav: (128, 86)
# Raw Mel spectrogram shape for T17_1003262.wav: (128, 86)
# Raw Mel spectrogram shape for T17_1003279.wav: (128, 91)
# Raw Mel spectrogram shape for T18_1003312.wav: (128, 123)
# Raw Mel spectrogram shape for T18_1003325.wav: (128, 105)
# Raw Mel spectrogram shape for T18_1003331.wav: (128, 113)
# Raw Mel spectrogram shape for T18_1003332.wav: (128, 150)
# Raw Mel spectrogram shape for T18_1003341.wav: (128, 101)
# Raw Mel spectrogram shape for T18_1003359.wav: (128, 102)
# Raw Mel spectrogram shape for T18_1003375.wav: (128, 99)
# Raw Mel spectrogram shape for T18_1003378.wav: (128, 99)
# Raw Mel spectrogram shape for T18_1003388.wav: (128, 85)
# Raw Mel spectrogram shape for T18_1003405.wav: (128, 101)
# Raw Mel spectrogram shape for T18_1003411.wav: (128, 126)
# Raw Mel spectrogram shape for T18_1003412.wav: (128, 122)
# Raw Mel spectrogram shape for T18_1003413.wav: (128, 114)
# Raw Mel spectrogram shape for T18_1003432.wav: (128, 126)
# Raw Mel spectrogram shape for T19_1003451.wav: (128, 66)
# Raw Mel spectrogram shape for T19_1003463.wav: (128, 130)
# Raw Mel spectrogram shape for T19_1003469.wav: (128, 115)
# Raw Mel spectrogram shape for T19_1003480.wav: (128, 79)
# Raw Mel spectrogram shape for T19_1003482.wav: (128, 91)
# Raw Mel spectrogram shape for T19_1003484.wav: (128, 54)
# Raw Mel spectrogram shape for T19_1003497.wav: (128, 77)
# Raw Mel spectrogram shape for T19_1003499.wav: (128, 91)
# Raw Mel spectrogram shape for T19_1003517.wav: (128, 95)
# Raw Mel spectrogram shape for T19_1003540.wav: (128, 90)
# Raw Mel spectrogram shape for T19_1003553.wav: (128, 77)
# Raw Mel spectrogram shape for T19_1003561.wav: (128, 63)
# Raw Mel spectrogram shape for T19_1003568.wav: (128, 54)
# Raw Mel spectrogram shape for T19_1003581.wav: (128, 61)
# Raw Mel spectrogram shape for T20_1003631.wav: (128, 119)
# Raw Mel spectrogram shape for T20_1003637.wav: (128, 82)
# Raw Mel spectrogram shape for T20_1003643.wav: (128, 89)
# Raw Mel spectrogram shape for T20_1003669.wav: (128, 111)
# Raw Mel spectrogram shape for T20_1003673.wav: (128, 87)
# Raw Mel spectrogram shape for T20_1003685.wav: (128, 111)
# Raw Mel spectrogram shape for T20_1003702.wav: (128, 113)
# Raw Mel spectrogram shape for T20_1003725.wav: (128, 127)
# Raw Mel spectrogram shape for T20_1003729.wav: (128, 95)
# Raw Mel spectrogram shape for T20_1003738.wav: (128, 109)
# Raw Mel spectrogram shape for T20_1003745.wav: (128, 102)
# Raw Mel spectrogram shape for T20_1003748.wav: (128, 127)
# Raw Mel spectrogram shape for T22_1002428.wav: (128, 107)
# Raw Mel spectrogram shape for T22_1002477.wav: (128, 130)
# Raw Mel spectrogram shape for T22_1002480.wav: (128, 81)
# Raw Mel spectrogram shape for T22_1002485.wav: (128, 118)
# Raw Mel spectrogram shape for T22_1002500.wav: (128, 74)
# Raw Mel spectrogram shape for T22_1002505.wav: (128, 89)
# Raw Mel spectrogram shape for T22_1002515.wav: (128, 89)
# Raw Mel spectrogram shape for T22_1002531.wav: (128, 90)
# Raw Mel spectrogram shape for T23_1003010.wav: (128, 99)
# Raw Mel spectrogram shape for T23_1003017.wav: (128, 117)
# Raw Mel spectrogram shape for T23_1003023.wav: (128, 71)
# Raw Mel spectrogram shape for T23_1003034.wav: (128, 61)
# Raw Mel spectrogram shape for T23_1003037.wav: (128, 77)
# Raw Mel spectrogram shape for T23_1003045.wav: (128, 81)
# Raw Mel spectrogram shape for T23_1003046.wav: (128, 65)
# Raw Mel spectrogram shape for T23_1003047.wav: (128, 83)
# Raw Mel spectrogram shape for T23_1003054.wav: (128, 77)
# Raw Mel spectrogram shape for T23_1003056.wav: (128, 55)
# Raw Mel spectrogram shape for T23_1003082.wav: (128, 79)
# Raw Mel spectrogram shape for T23_1003098.wav: (128, 94)
# Raw Mel spectrogram shape for T23_1003105.wav: (128, 91)
# Raw Mel spectrogram shape for T23_1003112.wav: (128, 65)
# Raw Mel spectrogram shape for T23_1003119.wav: (128, 89)
# Raw Mel spectrogram shape for T23_1003121.wav: (128, 83)
# Raw Mel spectrogram shape for T25_1002710.wav: (128, 147)
# Raw Mel spectrogram shape for T25_1002715.wav: (128, 187)
# Raw Mel spectrogram shape for T25_1002716.wav: (128, 175)
# Raw Mel spectrogram shape for T25_1002721.wav: (128, 114)
# Raw Mel spectrogram shape for T25_1002733.wav: (128, 219)
# Raw Mel spectrogram shape for T25_1002734.wav: (128, 122)
# Raw Mel spectrogram shape for T25_1002741.wav: (128, 97)
# Raw Mel spectrogram shape for T25_1002773.wav: (128, 138)
# Raw Mel spectrogram shape for T25_1002776.wav: (128, 105)
# Raw Mel spectrogram shape for T25_1002784.wav: (128, 150)
# Raw Mel spectrogram shape for T25_1002785.wav: (128, 97)
# Raw Mel spectrogram shape for T25_1002816.wav: (128, 147)
# Raw Mel spectrogram shape for T25_1002825.wav: (128, 110)
# Raw Mel spectrogram shape for T25_1002844.wav: (128, 130)
# Raw Mel spectrogram shape for T25_1002848.wav: (128, 133)
# Raw Mel spectrogram shape for T25_1002849.wav: (128, 125)
# Raw Mel spectrogram shape for T3_1002347.wav: (128, 66)
# Raw Mel spectrogram shape for T3_1002354.wav: (128, 87)
# Raw Mel spectrogram shape for T3_1002362.wav: (128, 81)
# Raw Mel spectrogram shape for T3_1002368.wav: (128, 106)
# Raw Mel spectrogram shape for T3_1002375.wav: (128, 75)
# Raw Mel spectrogram shape for T3_1002376.wav: (128, 79)
# Raw Mel spectrogram shape for T3_1002387.wav: (128, 114)
# Raw Mel spectrogram shape for T3_1002392.wav: (128, 57)
# Raw Mel spectrogram shape for T3_1002394.wav: (128, 67)
# Raw Mel spectrogram shape for E10000122.wav: (128, 86)
# Raw Mel spectrogram shape for E10000123.wav: (128, 63)
# Raw Mel spectrogram shape for E10000125.wav: (128, 63)
# Raw Mel spectrogram shape for E10000127.wav: (128, 67)
# Raw Mel spectrogram shape for E10000129.wav: (128, 101)
# Raw Mel spectrogram shape for E10000134.wav: (128, 47)
# Raw Mel spectrogram shape for E10000135.wav: (128, 152)
# Raw Mel spectrogram shape for E10000136.wav: (128, 133)
# Raw Mel spectrogram shape for E10000137.wav: (128, 128)
# Raw Mel spectrogram shape for E10000145.wav: (128, 139)
# Raw Mel spectrogram shape for E10000148.wav: (128, 103)
# Raw Mel spectrogram shape for E10000149.wav: (128, 115)
# Raw Mel spectrogram shape for E10000154.wav: (128, 80)
# Raw Mel spectrogram shape for E10000155.wav: (128, 95)
# Raw Mel spectrogram shape for E10000157.wav: (128, 143)
# Raw Mel spectrogram shape for E10000160.wav: (128, 142)
# Raw Mel spectrogram shape for E10000161.wav: (128, 97)
# Raw Mel spectrogram shape for E10000162.wav: (128, 88)
# Raw Mel spectrogram shape for E10000165.wav: (128, 83)
# Raw Mel spectrogram shape for E10000169.wav: (128, 153)
# Raw Mel spectrogram shape for E10000170.wav: (128, 55)
# Raw Mel spectrogram shape for E10000183.wav: (128, 88)
# Raw Mel spectrogram shape for E10000186.wav: (128, 68)
# Raw Mel spectrogram shape for E10000187.wav: (128, 115)
# Raw Mel spectrogram shape for E10000188.wav: (128, 81)
# Raw Mel spectrogram shape for E10000192.wav: (128, 126)
# Raw Mel spectrogram shape for E10000194.wav: (128, 104)
# Raw Mel spectrogram shape for E10000195.wav: (128, 96)
# Raw Mel spectrogram shape for E10000198.wav: (128, 167)
# Raw Mel spectrogram shape for E10000199.wav: (128, 96)
# Raw Mel spectrogram shape for E10000203.wav: (128, 99)
# Raw Mel spectrogram shape for E10000207.wav: (128, 83)
# Raw Mel spectrogram shape for E10000209.wav: (128, 139)
# Raw Mel spectrogram shape for E10000211.wav: (128, 57)
# Raw Mel spectrogram shape for E10000212.wav: (128, 192)
# Raw Mel spectrogram shape for E10000220.wav: (128, 89)
# Raw Mel spectrogram shape for E10000222.wav: (128, 90)
# Raw Mel spectrogram shape for E10000226.wav: (128, 50)
# Raw Mel spectrogram shape for E10000228.wav: (128, 51)
# Raw Mel spectrogram shape for E10000229.wav: (128, 108)
# Raw Mel spectrogram shape for E10000231.wav: (128, 132)
# Raw Mel spectrogram shape for E10000232.wav: (128, 55)
# Raw Mel spectrogram shape for E10000235.wav: (128, 91)
# Raw Mel spectrogram shape for E10000239.wav: (128, 109)
# Raw Mel spectrogram shape for E10000241.wav: (128, 151)
# Raw Mel spectrogram shape for E10000243.wav: (128, 140)
# Raw Mel spectrogram shape for T10_1006321.wav: (128, 96)
# Raw Mel spectrogram shape for T10_1006419.wav: (128, 213)
# Raw Mel spectrogram shape for T10_1006602.wav: (128, 119)
# Raw Mel spectrogram shape for T10_1006608.wav: (128, 103)
# Raw Mel spectrogram shape for T10_1006676.wav: (128, 136)
# Raw Mel spectrogram shape for T10_1006688.wav: (128, 127)
# Raw Mel spectrogram shape for T10_1006704.wav: (128, 72)
# Raw Mel spectrogram shape for T10_1006762.wav: (128, 86)
# Raw Mel spectrogram shape for T10_1006777.wav: (128, 72)
# Raw Mel spectrogram shape for T16_1013515.wav: (128, 103)
# Raw Mel spectrogram shape for T16_1013530.wav: (128, 80)
# Raw Mel spectrogram shape for T17_1014398.wav: (128, 161)
# Raw Mel spectrogram shape for T18_1014985.wav: (128, 99)
# Raw Mel spectrogram shape for T18_1014994.wav: (128, 74)
# Raw Mel spectrogram shape for T18_1015150.wav: (128, 93)
# Raw Mel spectrogram shape for T18_1015336.wav: (128, 111)
# Raw Mel spectrogram shape for T19_1015445.wav: (128, 65)
# Raw Mel spectrogram shape for T19_1015510.wav: (128, 62)
# Raw Mel spectrogram shape for T19_1015534.wav: (128, 85)
# Raw Mel spectrogram shape for T19_1015579.wav: (128, 44)
# Raw Mel spectrogram shape for T19_1015616.wav: (128, 122)
# Raw Mel spectrogram shape for T19_1015673.wav: (128, 59)
# Raw Mel spectrogram shape for T19_1015714.wav: (128, 50)
# Raw Mel spectrogram shape for T19_1015836.wav: (128, 148)
# Raw Mel spectrogram shape for T20_1016193.wav: (128, 72)
# Raw Mel spectrogram shape for T20_1016326.wav: (128, 76)
# Raw Mel spectrogram shape for T20_1016329.wav: (128, 72)
# Raw Mel spectrogram shape for T21_1006834.wav: (128, 90)
# Raw Mel spectrogram shape for T21_1006865.wav: (128, 140)
# Raw Mel spectrogram shape for T21_1006893.wav: (128, 71)
# Raw Mel spectrogram shape for T21_1006947.wav: (128, 166)
# Raw Mel spectrogram shape for T21_1007069.wav: (128, 83)
# Raw Mel spectrogram shape for T23_1013969.wav: (128, 71)
# Raw Mel spectrogram shape for T23_1014234.wav: (128, 63)
# Raw Mel spectrogram shape for T24_1010328.wav: (128, 109)
# Raw Mel spectrogram shape for T24_1010344.wav: (128, 63)
# Raw Mel spectrogram shape for T24_1010361.wav: (128, 153)
# Raw Mel spectrogram shape for T24_1010375.wav: (128, 66)
# Raw Mel spectrogram shape for T24_1010379.wav: (128, 80)
# Raw Mel spectrogram shape for T24_1010538.wav: (128, 185)
# Raw Mel spectrogram shape for T24_1010623.wav: (128, 59)
# Raw Mel spectrogram shape for T24_1010633.wav: (128, 109)
# Raw Mel spectrogram shape for T24_1010650.wav: (128, 83)
# Raw Mel spectrogram shape for T24_1010717.wav: (128, 152)
# Raw Mel spectrogram shape for T2_1003970.wav: (128, 101)
# Raw Mel spectrogram shape for T2_1004097.wav: (128, 75)
# Raw Mel spectrogram shape for T2_1004247.wav: (128, 100)
# Raw Mel spectrogram shape for T3_1011442.wav: (128, 97)
# Raw Mel spectrogram shape for T3_1011537.wav: (128, 123)
# Raw Mel spectrogram shape for T3_1011543.wav: (128, 129)
# Raw Mel spectrogram shape for T3_1011559.wav: (128, 106)
# Raw Mel spectrogram shape for T3_1011589.wav: (128, 48)
# Raw Mel spectrogram shape for T3_1011623.wav: (128, 89)
# Raw Mel spectrogram shape for T3_1011664.wav: (128, 42)
# Raw Mel spectrogram shape for T3_1011674.wav: (128, 83)
# Raw Mel spectrogram shape for T4_1004359.wav: (128, 130)
# Raw Mel spectrogram shape for T4_1004377.wav: (128, 115)
# Raw Mel spectrogram shape for T4_1004629.wav: (128, 83)
# Raw Mel spectrogram shape for T4_1004717.wav: (128, 111)
# Raw Mel spectrogram shape for T4_1004735.wav: (128, 75)
# Raw Mel spectrogram shape for T5_1004858.wav: (128, 112)
# Raw Mel spectrogram shape for T5_1004906.wav: (128, 129)
# Raw Mel spectrogram shape for T5_1005009.wav: (128, 121)
# Raw Mel spectrogram shape for T5_1005016.wav: (128, 76)
# Raw Mel spectrogram shape for T7_1005391.wav: (128, 79)
# Raw Mel spectrogram shape for T7_1005418.wav: (128, 107)
# Raw Mel spectrogram shape for T7_1005536.wav: (128, 116)
# Raw Mel spectrogram shape for T7_1005652.wav: (128, 109)
# Raw Mel spectrogram shape for T7_1005662.wav: (128, 163)
# Raw Mel spectrogram shape for T8_1010847.wav: (128, 97)
# Raw Mel spectrogram shape for T8_1010859.wav: (128, 52)
# Raw Mel spectrogram shape for T8_1010993.wav: (128, 179)
# Raw Mel spectrogram shape for T8_1010994.wav: (128, 120)
# Raw Mel spectrogram shape for T8_1011023.wav: (128, 141)
# Raw Mel spectrogram shape for T8_1011057.wav: (128, 87)
# Raw Mel spectrogram shape for T8_1011082.wav: (128, 107)
# Raw Mel spectrogram shape for T8_1011119.wav: (128, 98)
# Raw Mel spectrogram shape for T8_1011228.wav: (128, 132)
# Raw Mel spectrogram shape for T8_1011265.wav: (128, 179)
# Raw Mel spectrogram shape for T8_1011284.wav: (128, 85)
# Raw Mel spectrogram shape for T8_1011292.wav: (128, 148)
# Raw Mel spectrogram shape for T9_1005851.wav: (128, 157)
# Raw Mel spectrogram shape for T9_1005969.wav: (128, 109)
# Raw Mel spectrogram shape for T9_1006039.wav: (128, 109)
# Raw Mel spectrogram shape for T9_1006092.wav: (128, 81)
# Raw Mel spectrogram shape for T9_1006112.wav: (128, 129)
# Raw Mel spectrogram shape for T9_1006124.wav: (128, 99)
# Raw Mel spectrogram shape for T9_1006142.wav: (128, 113)
# New MFCC shape: (268, 13)
# New Mel spectrogram shape: (268, 128, 44, 1)
# New Wav2Vec shape: (268, 1024)
# New Labels shape: (268,)

# %%
import os

def get_audio_files(dataset_path):
    audio_files = []
    # Loop through each subdirectory in the dataset
    for root, _, files in os.walk(dataset_path):
        for file in files:
            # Check if the file is a .wav file
            if file.endswith('.wav'):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Specify the path to your new dataset
new_dataset_path = r'C:\Users\ACER\Desktop\ASV 2015\Train'
file_list = get_audio_files(new_dataset_path)

# %%
def pad_mel_spectrogram(mel_spectrogram, target_width=44):
    # Check the current width
    current_width = mel_spectrogram.shape[1]
    if current_width < target_width:
        # Pad with zeros on the right
        padding_width = target_width - current_width
        padded_mel = np.pad(mel_spectrogram, ((0, 0), (0, padding_width)), mode='constant')
    elif current_width > target_width:
        # Crop the mel spectrogram
        padded_mel = mel_spectrogram[:, :target_width]
    else:
        padded_mel = mel_spectrogram
    return padded_mel.reshape((128, target_width, 1))  # Reshape to (128, target_width, 1)

# Apply the padding function in your extraction loop
mel_spectrogram_features = []

for file in file_list:  # Your list of audio files
    mel_spec = extract_mel_spectrogram(file)
    mel_spec_padded = pad_mel_spectrogram(mel_spec)
    mel_spectrogram_features.append(mel_spec_padded)

# %%
# Load your previously saved model
from tensorflow.keras.models import load_model

# Load the model
model = load_model('audio_deepfake_model.h5')

# Train the model on the new dataset
history = model.fit(
    [X_mfcc_new, X_mel_new, X_wav2vec_new],  # Input features
    y_new,  # Target labels
    epochs=50,  # Adjust the number of epochs as necessary
    batch_size=32,  # Adjust batch size as necessary
    validation_split=0.2,  # Use 20% of the data for validation
    verbose=1  # Set to 1 to see the training progress
)

# Save the retrained model
model.save('retrained_audio_deepfake_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 8
#       5 model = load_model('audio_deepfake_model.h5')
#       7 # Train the model on the new dataset
# ----> 8 history = model.fit(
#       9     [X_mfcc_new, X_mel_new, X_wav2vec_new],  # Input features
#      10     y_new,  # Target labels
#      11     epochs=50,  # Adjust the number of epochs as necessary
#      12     batch_size=32,  # Adjust batch size as necessary
#      13     validation_split=0.2,  # Use 20% of the data for validation
#      14     verbose=1  # Set to 1 to see the training progress
#      15 )
#      17 # Save the retrained model
#      18 model.save('retrained_audio_deepfake_model.h5')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 1 of layer "functional_1" is incompatible with the layer: expected shape=(None, 128, 63, 1), found shape=(None, 128, 44)
